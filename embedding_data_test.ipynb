# %% [markdown]
# <a href="https://colab.research.google.com/github/ShawnLiu119/Chatbot_CardBenefit_LLM_MilvusRAG/blob/main/embedding_data_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.5/973.5 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.2/310.2 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.4/124.4 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 3.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ...

# %%
pip install langchain-community langchain-core
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 4.3 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import RecursiveUrlLoader

DOCS_PAGE="https://milvus.io/docs/"

loader = RecursiveUrlLoader(DOCS_PAGE)
docs = loader.load()

num_documents = len(docs)
print(f"loaded {num_documents} documents")
# Out:
# loaded 23 documents

# %%
type(docs)
# Out:
# list

# %%
docs[1].page_content
# Out:
# '<!DOCTYPE html><html><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width"/><link rel="icon" href="/favicon-32x32.png"/><meta name="image" property="og:image" content="https://assets.zilliz.com/meta_image_milvus_d6510e10e0.png"/><meta property="og:type" content="WebSite"/><title>Overview | Milvus Documentation</title><meta name="description" content="Learn how Prometheus and Grafana are used in Milvus for montoring and alerting services."/><meta property="og:title" content="Overview | Milvus Documentation"/><meta property="og:description" content="Learn how Prometheus and Grafana are used in Milvus for montoring and alerting services."/><meta property="og:url" content="https://milvus.io/docs/monitor_overview.md"/><meta name="docsearch:language" content="en"/><meta name="docsearch:version" content="v2.4.x"/><meta name="next-head-count" content="12"/><link rel="preconnect" href="https://fonts.googleapis.com"/><link rel="preconnect" href="https://fonts.gstatic
# ...

# %%
#test for Fingerhut dataset

from langchain_community.document_loaders import RecursiveUrlLoader

DOCS_PAGE="https://www.fingerhut.com/content/footer-terms"

loader = RecursiveUrlLoader(DOCS_PAGE)
docs = loader.load()

num_documents = len(docs)
print(f"loaded {num_documents} documents")
# Out:
# loaded 1 documents

# %%
from langchain_community.document_loaders import RecursiveUrlLoader

DOCS_PAGE="https://www.fingerhut.com/content/CreditTC?pageName=CreditTC"

loader = RecursiveUrlLoader(DOCS_PAGE)
docs = loader.load()

num_documents = len(docs)
print(f"loaded {num_documents} documents")
# Out:
# loaded 1 documents

# %%
DOCS_PAGE="https://www.fingerhut.com/content/faqs-fetti"

loader = RecursiveUrlLoader(DOCS_PAGE)
docs = loader.load()

num_documents = len(docs)
print(f"loaded {num_documents} documents")
# Out:
# loaded 1 documents
